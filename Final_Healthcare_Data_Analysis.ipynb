# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import warnings
import seaborn as sb
from sklearn.linear_model import LinearRegression
from scipy import stats
from scipy.stats import linregress
import requests

# Suppress all warnings
warnings.filterwarnings("ignore")

# %%
# Load datasets
healthcare_population_raw = "Data_Files_Healthcare_Project/healthcare_population_raw_data.csv"
raw_data = "Data_Files_Healthcare_Project/raw_data.csv"
insurance_coverage_rates = "Data_Files_Healthcare_Project/Coverage Rates of Health Insurance Types By States.xlsx"

paths = [
    "Data_Files_Healthcare_Project/healthcare_population_raw_data.csv",
    "Data_Files_Healthcare_Project/raw_data.csv",
    "Data_Files_Healthcare_Project/Coverage Rates of Health Insurance Types By States.csv"]

# %%
# Create DataFrames
healthcare_population_raw = pd.read_csv('Data_Files_Healthcare_Project/healthcare_population_raw_data.csv')
raw_data = pd.read_csv('Data_Files_Healthcare_Project/raw_data.csv')
insurance_coverage_rates = pd.read_excel('Data_Files_Healthcare_Project/Coverage Rates of Health Insurance Types By States.xlsx')

# %%
# Display the first few rows of each dataset
print("Healthcare Population Raw Sample:\n", healthcare_population_raw.head())
print("\nRaw Data Sample:\n", raw_data.head())
print("/Insurance Coverage Rates Sample:\n", insurance_coverage_rates.head())
# Out:
# Healthcare Population Raw Sample:
#    Title: Health Care Expenditures by State of Residence (in millions) | KFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Unnamed: 1  Unnamed: 2      Unnamed: 3       Unnamed: 4  \
# 0         NaN         NaN  State Pop 2020  Timeframe: 2020
# 1         NaN         NaN             NaN         Location
# 2         NaN         NaN     331,526,933    United States
# 3         NaN         NaN       5,031,864          Alabama
# 4         NaN         NaN         732,964           Alaska
#
#               Unnamed: 5      Unnamed: 6       Unnamed: 7  \
# 0                    NaN  State Pop 2019  Timeframe: 2019
# 1  Total Health Spending             NaN         Location
# 2            $3,357,832      328,239,523    United States
# 3               $45,673        4,903,185          Alabama
# 4                $9,975          731,545           Alaska
#
#               Unnamed: 8      Unnamed: 9  ...            Unnamed: 23  \
# 0                    NaN  State Pop 2018  ...                    NaN
# 1  Total Health Spending             NaN  ...  Total Health Spending
# 2            $3,175,230      326,687,501  ...            $2,527,325
# 3               $42,903        4,887,681  ...               $35,248
# 4                $9,702          735,139  ...                $7,765
#
#       Unnamed: 24      Unnamed: 25            Unnamed: 26     Unnamed: 27  \
# 0  State Pop 2013  Timeframe: 2013                    NaN  State Pop 2012
# 1             NaN         Location  Total Health Spending             NaN
# 2     315,993,715    United States            $2,405,667      313,830,990
# 3       4,830,081          Alabama               $33,670        4,815,588
# 4         737,068           Alaska                $7,439          730,443
#
#        Unnamed: 28            Unnamed: 29     Unnamed: 30      Unnamed: 31  \
# 0  Timeframe: 2012                    NaN  State Pop 2011  Timeframe: 2011
# 1         Location  Total Health Spending             NaN         Location
# 2    United States            $2,346,962      311,556,874    United States
# 3          Alabama               $32,740        4,799,069          Alabama
# 4           Alaska                $7,257          722,128           Alaska
#
#              Unnamed: 32
# 0                    NaN
# 1  Total Health Spending
# 2            $2,254,675
# 3               $31,262
# 4                $6,749
#
# [5 rows x 33 columns]
#
# Raw Data Sample:
#    Title: Health Care Expenditures by State of Residence (in millions) | KFF  \
# 0                                    Timeframe: 2020
# 1                                           Location
# 2                                      United States
# 3                                            Alabama
# 4                                             Alaska
#
#               Unnamed: 1  Unnamed: 2       Unnamed: 3             Unnamed: 4  \
# 0                    NaN         NaN  Timeframe: 2019                    NaN
# 1  Total Health Spending         NaN         Location  Total Health Spending
# 2            $3,357,832          NaN    United States            $3,175,230
# 3               $45,673          NaN          Alabama               $42,903
# 4                $9,975          NaN           Alaska                $9,702
#
#         Unnamed: 5             Unnamed: 6       Unnamed: 7  \
# 0  Timeframe: 2018                    NaN  Timeframe: 2017
# 1         Location  Total Health Spending         Location
# 2    United States            $3,021,796     United States
# 3          Alabama               $40,810           Alabama
# 4           Alaska                $9,352            Alaska
#
#               Unnamed: 8       Unnamed: 9  ...      Unnamed: 15  \
# 0                    NaN  Timeframe: 2016  ...  Timeframe: 2014
# 1  Total Health Spending         Location  ...         Location
# 2            $2,905,160     United States  ...    United States
# 3               $39,778           Alabama  ...          Alabama
# 4                $9,116            Alaska  ...           Alaska
#
#              Unnamed: 16      Unnamed: 17            Unnamed: 18  \
# 0                    NaN  Timeframe: 2013                    NaN
# 1  Total Health Spending         Location  Total Health Spending
# 2            $2,527,325     United States            $2,405,667
# 3               $35,248           Alabama               $33,670
# 4                $7,765            Alaska                $7,439
#
#        Unnamed: 19            Unnamed: 20      Unnamed: 21  \
# 0  Timeframe: 2012                    NaN  Timeframe: 2011
# 1         Location  Total Health Spending         Location
# 2    United States            $2,346,962     United States
# 3          Alabama               $32,740           Alabama
# 4           Alaska                $7,257            Alaska
#
#              Unnamed: 22      Unnamed: 23            Unnamed: 24
# 0                    NaN  Timeframe: 2010                    NaN
# 1  Total Health Spending         Location  Total Health Spending
# 2            $2,254,675     United States            $2,181,261
# 3               $31,262           Alabama               $30,655
# 4                $6,749            Alaska                $6,373
#
# [5 rows x 25 columns]
# /Insurance Coverage Rates Sample:
#    Table with row headers in columns A and B and column headers in rows 4 through 5  \
# 0  Table HIC-4_ACS. Health Insurance Coverage Sta...
# 1  Note: Numbers in thousands. Civilian noninstit...
# 2                                       Nation/State
# 3                                                NaN
# 4                                      United States
#
#   Unnamed: 1 Unnamed: 2         Unnamed: 3 Unnamed: 4         Unnamed: 5  \
# 0        NaN        NaN                NaN        NaN                NaN
# 1        NaN        NaN                NaN        NaN                NaN
# 2   Coverage       2023                NaN        NaN                NaN
# 3        NaN   Estimate  Margin of error 1    Percent  Margin of error 1
# 4      Total     330000                 20        100                  0
#
#   Unnamed: 6         Unnamed: 7 Unnamed: 8         Unnamed: 9  ...  \
# 0        NaN                NaN        NaN                NaN  ...
# 1        NaN                NaN        NaN                NaN  ...
# 2       2022                NaN        NaN                NaN  ...
# 3   Estimate  Margin of error 1    Percent  Margin of error 1  ...
# 4     328300                 17        100                  0  ...
#
#   Unnamed: 56        Unnamed: 57 Unnamed: 58        Unnamed: 59 Unnamed: 60  \
# 0         NaN                NaN         NaN                NaN         NaN
# 1         NaN                NaN         NaN                NaN         NaN
# 2         NaN                NaN        2009                NaN         NaN
# 3     Percent  Margin of error 1    Estimate  Margin of error 1     Percent
# 4         100                  0      301500                 23         100
#
#          Unnamed: 61 Unnamed: 62        Unnamed: 63 Unnamed: 64  \
# 0                NaN         NaN                NaN         NaN
# 1                NaN         NaN                NaN         NaN
# 2                NaN        2008                NaN         NaN
# 3  Margin of error 1    Estimate  Margin of error 1     Percent
# 4                  0      298600                 20         100
#
#          Unnamed: 65
# 0                NaN
# 1                NaN
# 2                NaN
# 3  Margin of error 1
# 4                  0
#
# [5 rows x 66 columns]

# %%
# Data Cleaning of raw_data
#Load data
file_path = "Data_Files_Healthcare_Project/raw_data.csv"
raw_data = pd.read_csv(file_path, header=None)

# Step 1 Remove metadata rows
raw_data = raw_data.iloc[2:]

#raw_data

# Drop columns by index
raw_data = raw_data.drop(columns=[2, 11, 14])

raw_data = raw_data.iloc[:53]

#Display modified DataFrame
print(raw_data.tail(52))
# Out:
#                       0            1                     3            4   \
# 3          United States  $3,357,832          United States  $3,175,230
# 4                Alabama     $45,673                Alabama     $42,903
# 5                 Alaska      $9,975                 Alaska      $9,702
# 6                Arizona     $64,980                Arizona     $59,392
# 7               Arkansas     $28,300               Arkansas     $26,744
# 8             California    $405,451             California    $379,715
# 9               Colorado     $49,849               Colorado     $47,715
# 10           Connecticut     $44,425            Connecticut     $42,190
# 11              Delaware     $12,729               Delaware     $11,928
# 12  District of Columbia     $10,251   District of Columbia      $9,869
# 13               Florida    $214,408                Florida    $203,957
# 14               Georgia     $93,803                Georgia     $87,607
# 15                Hawaii     $14,480                 Hawaii     $13,526
# 16                 Idaho     $14,886                  Idaho     $13,817
# 17              Illinois    $128,263               Illinois    $120,291
# 18               Indiana     $71,040                Indiana     $66,818
# 19                  Iowa     $30,968                   Iowa     $29,046
# 20                Kansas     $27,414                 Kansas     $25,470
# 21              Kentucky     $45,922               Kentucky     $43,579
# 22             Louisiana     $48,845              Louisiana     $44,986
# 23                 Maine     $16,306                  Maine     $15,461
# 24              Maryland     $65,641               Maryland     $62,052
# 25         Massachusetts     $91,817          Massachusetts     $87,764
# 26              Michigan     $98,638               Michigan     $95,171
# 27             Minnesota     $61,357              Minnesota     $59,276
# 28           Mississippi     $27,870            Mississippi     $26,043
# 29              Missouri     $61,031               Missouri     $57,910
# 30               Montana     $11,035                Montana     $10,496
# 31              Nebraska     $20,371               Nebraska     $19,166
# 32                Nevada     $26,200                 Nevada     $25,079
# 33         New Hampshire     $16,113          New Hampshire     $15,391
# 34            New Jersey    $105,416             New Jersey    $100,152
# 35            New Mexico     $18,750             New Mexico     $17,761
# 36              New York    $270,847               New York    $251,696
# 37        North Carolina     $94,532         North Carolina     $90,508
# 38          North Dakota      $8,649           North Dakota      $8,136
# 39                  Ohio    $122,521                   Ohio    $118,988
# 40              Oklahoma     $37,595               Oklahoma     $35,343
# 41                Oregon     $42,716                 Oregon     $40,623
# 42          Pennsylvania    $148,327           Pennsylvania    $143,026
# 43          Rhode Island     $12,362           Rhode Island     $11,627
# 44        South Carolina     $45,742         South Carolina     $43,040
# 45          South Dakota     $11,154           South Dakota     $10,315
# 46             Tennessee     $64,295              Tennessee     $60,294
# 47                 Texas    $246,812                  Texas    $232,714
# 48                  Utah     $24,447                   Utah     $23,042
# 49               Vermont      $7,951                Vermont      $7,588
# 50              Virginia     $78,989               Virginia     $75,519
# 51            Washington     $71,277             Washington     $68,253
# 52         West Virginia     $22,790          West Virginia     $21,456
# 53             Wisconsin     $58,220              Wisconsin     $56,218
# 54               Wyoming      $6,399                Wyoming      $5,866
#
#                       5            6                     7            8   \
# 3          United States  $3,021,796          United States  $2,905,160
# 4                Alabama     $40,810                Alabama     $39,778
# 5                 Alaska      $9,352                 Alaska      $9,116
# 6                Arizona     $55,997                Arizona     $53,135
# 7               Arkansas     $25,740               Arkansas     $25,260
# 8             California    $357,648             California    $338,088
# 9               Colorado     $45,566               Colorado     $42,777
# 10           Connecticut     $40,671            Connecticut     $39,289
# 11              Delaware     $11,382               Delaware     $10,962
# 12  District of Columbia      $9,497   District of Columbia      $9,154
# 13               Florida    $194,444                Florida    $184,902
# 14               Georgia     $82,515                Georgia     $79,219
# 15                Hawaii     $12,711                 Hawaii     $12,113
# 16                 Idaho     $13,043                  Idaho     $12,481
# 17              Illinois    $116,019               Illinois    $113,085
# 18               Indiana     $62,275                Indiana     $60,057
# 19                  Iowa     $27,757                   Iowa     $26,801
# 20                Kansas     $24,411                 Kansas     $23,460
# 21              Kentucky     $41,659               Kentucky     $39,917
# 22             Louisiana     $42,994              Louisiana     $41,987
# 23                 Maine     $14,674                  Maine     $13,891
# 24              Maryland     $60,022               Maryland     $57,825
# 25         Massachusetts     $84,112          Massachusetts     $80,621
# 26              Michigan     $91,302               Michigan     $89,192
# 27             Minnesota     $57,064              Minnesota     $54,480
# 28           Mississippi     $25,106            Mississippi     $25,096
# 29              Missouri     $55,327               Missouri     $53,929
# 30               Montana      $9,932                Montana      $9,516
# 31              Nebraska     $18,278               Nebraska     $17,616
# 32                Nevada     $23,919                 Nevada     $22,714
# 33         New Hampshire     $14,871          New Hampshire     $14,278
# 34            New Jersey     $94,830             New Jersey     $91,907
# 35            New Mexico     $17,071             New Mexico     $16,687
# 36              New York    $236,451               New York    $226,458
# 37        North Carolina     $86,089         North Carolina     $83,286
# 38          North Dakota      $7,805           North Dakota      $7,538
# 39                  Ohio    $112,454                   Ohio    $109,656
# 40              Oklahoma     $34,014               Oklahoma     $32,972
# 41                Oregon     $38,354                 Oregon     $36,607
# 42          Pennsylvania    $139,741           Pennsylvania    $132,318
# 43          Rhode Island     $11,084           Rhode Island     $10,872
# 44        South Carolina     $40,606         South Carolina     $39,488
# 45          South Dakota      $9,749           South Dakota      $9,122
# 46             Tennessee     $58,053              Tennessee     $56,977
# 47                 Texas    $220,736                  Texas    $214,214
# 48                  Utah     $22,110                   Utah     $20,571
# 49               Vermont      $7,371                Vermont      $7,202
# 50              Virginia     $71,703               Virginia     $69,263
# 51            Washington     $64,637             Washington     $61,489
# 52         West Virginia     $20,475          West Virginia     $20,037
# 53             Wisconsin     $53,699              Wisconsin     $52,250
# 54               Wyoming      $5,667                Wyoming      $5,508
#
#                       9            10  ...                    15           16  \
# 3          United States  $2,795,322   ...         United States  $2,527,325
# 4                Alabama     $38,778   ...               Alabama     $35,248
# 5                 Alaska      $8,734   ...                Alaska      $7,765
# 6                Arizona     $49,926   ...               Arizona     $44,177
# 7               Arkansas     $24,172   ...              Arkansas     $21,624
# 8             California    $325,931   ...            California    $288,330
# 9               Colorado     $40,595   ...              Colorado     $35,757
# 10           Connecticut     $38,322   ...           Connecticut     $35,350
# 11              Delaware     $10,386   ...              Delaware      $9,577
# 12  District of Columbia      $8,836   ...  District of Columbia      $7,947
# 13               Florida    $175,724   ...               Florida    $158,144
# 14               Georgia     $75,794   ...               Georgia     $66,692
# 15                Hawaii     $11,490   ...                Hawaii     $10,225
# 16                 Idaho     $11,744   ...                 Idaho     $10,797
# 17              Illinois    $110,651   ...              Illinois    $103,304
# 18               Indiana     $58,251   ...               Indiana     $52,752
# 19                  Iowa     $26,519   ...                  Iowa     $24,782
# 20                Kansas     $22,851   ...                Kansas     $21,381
# 21              Kentucky     $38,238   ...              Kentucky     $35,183
# 22             Louisiana     $39,987   ...             Louisiana     $36,493
# 23                 Maine     $13,347   ...                 Maine     $12,134
# 24              Maryland     $55,993   ...              Maryland     $51,102
# 25         Massachusetts     $78,446   ...         Massachusetts     $70,311
# 26              Michigan     $86,674   ...              Michigan     $79,133
# 27             Minnesota     $52,711   ...             Minnesota     $48,633
# 28           Mississippi     $24,434   ...           Mississippi     $22,439
# 29              Missouri     $52,437   ...              Missouri     $47,429
# 30               Montana      $9,046   ...               Montana      $8,122
# 31              Nebraska     $17,050   ...              Nebraska     $15,368
# 32                Nevada     $21,537   ...                Nevada     $18,951
# 33         New Hampshire     $13,648   ...         New Hampshire     $12,498
# 34            New Jersey     $88,551   ...            New Jersey     $79,880
# 35            New Mexico     $16,148   ...            New Mexico     $14,653
# 36              New York    $214,568   ...              New York    $192,710
# 37        North Carolina     $80,133   ...        North Carolina     $71,488
# 38          North Dakota      $7,321   ...          North Dakota      $6,652
# 39                  Ohio    $105,481   ...                  Ohio     $97,506
# 40              Oklahoma     $31,943   ...              Oklahoma     $29,706
# 41                Oregon     $35,607   ...                Oregon     $31,323
# 42          Pennsylvania    $127,630   ...          Pennsylvania    $116,954
# 43          Rhode Island     $10,747   ...          Rhode Island     $10,020
# 44        South Carolina     $38,062   ...        South Carolina     $34,800
# 45          South Dakota      $8,676   ...          South Dakota      $7,735
# 46             Tennessee     $53,641   ...             Tennessee     $48,548
# 47                 Texas    $206,379   ...                 Texas    $184,011
# 48                  Utah     $19,477   ...                  Utah     $17,117
# 49               Vermont      $7,022   ...               Vermont      $6,626
# 50              Virginia     $67,233   ...              Virginia     $61,943
# 51            Washington     $59,104   ...            Washington     $53,652
# 52         West Virginia     $19,219   ...         West Virginia     $17,368
# 53             Wisconsin     $50,874   ...             Wisconsin     $48,163
# 54               Wyoming      $5,253   ...               Wyoming      $4,822
#
#                       17           18                    19           20  \
# 3          United States  $2,405,667          United States  $2,346,962
# 4                Alabama     $33,670                Alabama     $32,740
# 5                 Alaska      $7,439                 Alaska      $7,257
# 6                Arizona     $41,728                Arizona     $40,692
# 7               Arkansas     $20,188               Arkansas     $19,999
# 8             California    $277,008             California    $267,048
# 9               Colorado     $33,544               Colorado     $32,311
# 10           Connecticut     $33,944            Connecticut     $33,181
# 11              Delaware      $9,026               Delaware      $8,648
# 12  District of Columbia      $7,547   District of Columbia      $7,264
# 13               Florida    $148,646                Florida    $146,874
# 14               Georgia     $62,134                Georgia     $59,233
# 15                Hawaii      $9,693                 Hawaii      $9,401
# 16                 Idaho     $10,280                  Idaho     $10,027
# 17              Illinois     $99,230               Illinois     $96,681
# 18               Indiana     $50,242                Indiana     $49,815
# 19                  Iowa     $23,632                   Iowa     $23,222
# 20                Kansas     $20,954                 Kansas     $21,313
# 21              Kentucky     $33,048               Kentucky     $31,808
# 22             Louisiana     $34,518              Louisiana     $33,464
# 23                 Maine     $11,709                  Maine     $11,625
# 24              Maryland     $48,689               Maryland     $47,757
# 25         Massachusetts     $67,722          Massachusetts     $66,322
# 26              Michigan     $76,272               Michigan     $75,017
# 27             Minnesota     $46,204              Minnesota     $44,323
# 28           Mississippi     $21,536            Mississippi     $21,518
# 29              Missouri     $45,879               Missouri     $45,426
# 30               Montana      $7,812                Montana      $7,492
# 31              Nebraska     $14,793               Nebraska     $14,504
# 32                Nevada     $17,380                 Nevada     $16,623
# 33         New Hampshire     $12,193          New Hampshire     $11,869
# 34            New Jersey     $75,593             New Jersey     $73,747
# 35            New Mexico     $14,015             New Mexico     $13,944
# 36              New York    $183,912               New York    $177,831
# 37        North Carolina     $68,073         North Carolina     $67,949
# 38          North Dakota      $6,300           North Dakota      $5,939
# 39                  Ohio     $92,985                   Ohio     $90,723
# 40              Oklahoma     $28,193               Oklahoma     $27,547
# 41                Oregon     $28,953                 Oregon     $27,922
# 42          Pennsylvania    $112,482           Pennsylvania    $109,526
# 43          Rhode Island      $9,517           Rhode Island      $9,346
# 44        South Carolina     $32,974         South Carolina     $32,017
# 45          South Dakota      $7,310           South Dakota      $7,048
# 46             Tennessee     $46,311              Tennessee     $45,261
# 47                 Texas    $172,375                  Texas    $168,887
# 48                  Utah     $16,099                   Utah     $15,623
# 49               Vermont      $6,421                Vermont      $6,062
# 50              Virginia     $59,376               Virginia     $57,677
# 51            Washington     $51,245             Washington     $50,584
# 52         West Virginia     $16,491          West Virginia     $16,182
# 53             Wisconsin     $45,811              Wisconsin     $45,228
# 54               Wyoming      $4,571                Wyoming      $4,469
#
#                       21           22                    23           24
# 3          United States  $2,254,675          United States  $2,181,261
# 4                Alabama     $31,262                Alabama     $30,655
# 5                 Alaska      $6,749                 Alaska      $6,373
# 6                Arizona     $39,329                Arizona     $38,573
# 7               Arkansas     $19,237               Arkansas     $18,636
# 8             California    $253,703             California    $241,845
# 9               Colorado     $31,042               Colorado     $29,941
# 10           Connecticut     $31,975            Connecticut     $31,608
# 11              Delaware      $8,352               Delaware      $7,919
# 12  District of Columbia      $7,157   District of Columbia      $6,726
# 13               Florida    $140,543                Florida    $136,984
# 14               Georgia     $55,843                Georgia     $53,917
# 15                Hawaii      $8,913                 Hawaii      $8,785
# 16                 Idaho      $9,588                  Idaho      $9,282
# 17              Illinois     $93,941               Illinois     $91,925
# 18               Indiana     $46,300                Indiana     $44,522
# 19                  Iowa     $22,419                   Iowa     $21,647
# 20                Kansas     $20,291                 Kansas     $19,446
# 21              Kentucky     $31,022               Kentucky     $29,836
# 22             Louisiana     $32,600              Louisiana     $32,660
# 23                 Maine     $11,404                  Maine     $11,076
# 24              Maryland     $46,300               Maryland     $44,829
# 25         Massachusetts     $64,287          Massachusetts     $62,599
# 26              Michigan     $72,587               Michigan     $70,023
# 27             Minnesota     $42,841              Minnesota     $41,429
# 28           Mississippi     $20,064            Mississippi     $19,471
# 29              Missouri     $43,673               Missouri     $41,915
# 30               Montana      $7,132                Montana      $6,855
# 31              Nebraska     $13,954               Nebraska     $13,550
# 32                Nevada     $16,206                 Nevada     $15,643
# 33         New Hampshire     $11,511          New Hampshire     $11,120
# 34            New Jersey     $70,362             New Jersey     $68,770
# 35            New Mexico     $13,554             New Mexico     $13,276
# 36              New York    $175,327               New York    $169,932
# 37        North Carolina     $64,760         North Carolina     $62,408
# 38          North Dakota      $5,706           North Dakota      $5,406
# 39                  Ohio     $86,452                   Ohio     $85,358
# 40              Oklahoma     $26,284               Oklahoma     $25,057
# 41                Oregon     $27,057                 Oregon     $25,903
# 42          Pennsylvania    $106,707           Pennsylvania    $102,564
# 43          Rhode Island      $9,132           Rhode Island      $8,916
# 44        South Carolina     $31,018         South Carolina     $30,164
# 45          South Dakota      $6,717           South Dakota      $6,339
# 46             Tennessee     $43,128              Tennessee     $42,134
# 47                 Texas    $160,518                  Texas    $154,260
# 48                  Utah     $14,862                   Utah     $14,245
# 49               Vermont      $5,776                Vermont      $5,539
# 50              Virginia     $55,019               Virginia     $52,541
# 51            Washington     $47,939             Washington     $46,608
# 52         West Virginia     $15,242          West Virginia     $14,687
# 53             Wisconsin     $44,646              Wisconsin     $43,276
# 54               Wyoming      $4,246                Wyoming      $4,090
#
# [52 rows x 22 columns]

# %%
# Step 2: Set appropriate column names
years = range(2020, 2009, -1) # Adjust range based on the number of years
columns = []

print (years)
# Out:
# range(2020, 2009, -1)

# %%
print("Value of years:", years)
print("Type of years:", type(years))
# Out:
# Value of years: range(2020, 2009, -1)
# Type of years: <class 'range'>

# %%
for year in years:
    columns.extend([f'Location_{year}', f'Total Health Spending_{year}'])

if len(columns) == raw_data.shape[1]:
    raw_data.columns = columns
else:
    print("Error: Mismatch in column count.")

# %%
# Step 3: Reshape the data by unpivoting each year into rows
data_cleaned = pd.DataFrame()

# %%
for year in years:
    # Select location and spending columns for the specific year
    year_data = raw_data[[f'Location_{year}', f'Total Health Spending_{year}']].copy()
    year_data.columns = ['State', 'Total Health Spending']
    year_data['Year'] = year
    data_cleaned = pd.concat([data_cleaned, year_data])

# %%
# Step 4: Remove any rows where 'State is Nan (in case of any empty rows from combining data)
data_cleaned = data_cleaned.dropna(subset=['State'])

# %%
# Cleaning data
data_cleaned = data_cleaned[data_cleaned['State'] != "Location"]
data_cleaned = data_cleaned[data_cleaned['State'] != "United Stated"]

# %%
# Step 5: Convert 'Total Health Spending' to numeric by removing any non-numeric characters
data_cleaned['Total Health Spending'] = data_cleaned['Total Health Spending'].replace('[\$]', '', regex=True)

# %%
# Reset the index
data_cleaned.reset_index(drop=True, inplace=True)

# %%
# Display the cleaned data
print(data_cleaned.head(10))
data_cleaned.to_csv('raw_data_cleaned.csv')

raw_data_cleaned = data_cleaned
# Out:
#                   State Total Health Spending  Year
# 0         United States            3,357,832   2020
# 1               Alabama               45,673   2020
# 2                Alaska                9,975   2020
# 3               Arizona               64,980   2020
# 4              Arkansas               28,300   2020
# 5            California              405,451   2020
# 6              Colorado               49,849   2020
# 7           Connecticut               44,425   2020
# 8              Delaware               12,729   2020
# 9  District of Columbia               10,251   2020

# %%
# Data Cleaning of healthcare_population_raw_data

# %%
# Load the data 
file_path = 'Data_Files_Healthcare_Project/healthcare_population_raw_data.csv'
healthcare_population_raw_data = pd.read_csv(file_path, header=None)

# Step 1: Remove metadata rows
healthcare_population_raw_data = healthcare_population_raw_data.iloc[2:]

#raw_data

# Drop columns by index
healthcare_population_raw_data = healthcare_population_raw_data.drop(columns=[0, 1, 2])

#healthcare_population_raw = healthcare_population_raw.iloc[:53]


# Display the modified DataFrame
print(healthcare_population_raw_data.head(5))
# Out:
#             3              4                      5            6   \
# 2          NaN       Location  Total Health Spending          NaN
# 3  331,526,933  United States            $3,357,832   328,239,523
# 4    5,031,864        Alabama               $45,673     4,903,185
# 5      732,964         Alaska                $9,975       731,545
# 6    7,186,683        Arizona               $64,980     7,278,717
#
#               7                      8            9              10  \
# 2       Location  Total Health Spending          NaN       Location
# 3  United States            $3,175,230   326,687,501  United States
# 4        Alabama               $42,903     4,887,681        Alabama
# 5         Alaska                $9,702       735,139         Alaska
# 6        Arizona               $59,392     7,158,024        Arizona
#
#                       11           12  ...                     23  \
# 2  Total Health Spending          NaN  ...  Total Health Spending
# 3            $3,021,796   324,985,539  ...            $2,527,325
# 4               $40,810     4,874,486  ...               $35,248
# 5                $9,352       739,700  ...                $7,765
# 6               $55,997     7,044,008  ...               $44,177
#
#             24             25                     26           27  \
# 2          NaN       Location  Total Health Spending          NaN
# 3  315,993,715  United States            $2,405,667   313,830,990
# 4    4,830,081        Alabama               $33,670     4,815,588
# 5      737,068         Alaska                $7,439       730,443
# 6    6,632,764        Arizona               $41,728     6,554,978
#
#               28                     29           30             31  \
# 2       Location  Total Health Spending          NaN       Location
# 3  United States            $2,346,962   311,556,874  United States
# 4        Alabama               $32,740     4,799,069        Alabama
# 5         Alaska                $7,257       722,128         Alaska
# 6        Arizona               $40,692     6,472,643        Arizona
#
#                       32
# 2  Total Health Spending
# 3            $2,254,675
# 4               $31,262
# 5                $6,749
# 6               $39,329
#
# [5 rows x 30 columns]

# %%
# Step 2: Set appropriate column names
# Assuming the columns are organized as: Location, Spending for each year, starting from 2020 and moving backwards
years = range(2020, 2010, -1)  # Adjust range based on the number of years in the file
columns = []

print(years)
# Out:
# range(2020, 2010, -1)

# %%
for year in years:
    columns.extend([f'Pop_{year}',f'Location_{year}', f'Total Health Spending_{year}'])

healthcare_population_raw_data.columns = columns

# %%
healthcare_population_raw_data
# Out:
#        Pop_2020  Location_2020 Total Health Spending_2020     Pop_2019  \
# 2           NaN       Location      Total Health Spending          NaN
# 3   331,526,933  United States                $3,357,832   328,239,523
# 4     5,031,864        Alabama                   $45,673     4,903,185
# 5       732,964         Alaska                    $9,975       731,545
# 6     7,186,683        Arizona                   $64,980     7,278,717
# ..          ...            ...                        ...          ...
# 65          NaN            NaN                        NaN          NaN
# 66          NaN            NaN                        NaN          NaN
# 67          NaN            NaN                        NaN          NaN
# 68          NaN            NaN                        NaN          NaN
# 69          NaN            NaN                        NaN          NaN
#
#     Location_2019 Total Health Spending_2019     Pop_2018  Location_2018  \
# 2        Location      Total Health Spending          NaN       Location
# 3   United States                $3,175,230   326,687,501  United States
# 4         Alabama                   $42,903     4,887,681        Alabama
# 5          Alaska                    $9,702       735,139         Alaska
# 6         Arizona                   $59,392     7,158,024        Arizona
# ..            ...                        ...          ...            ...
# 65            NaN                        NaN          NaN            NaN
# 66            NaN                        NaN          NaN            NaN
# 67            NaN                        NaN          NaN            NaN
# 68            NaN                        NaN          NaN            NaN
# 69            NaN                        NaN          NaN            NaN
#
#    Total Health Spending_2018     Pop_2017  ... Total Health Spending_2014  \
# 2       Total Health Spending          NaN  ...      Total Health Spending
# 3                 $3,021,796   324,985,539  ...                $2,527,325
# 4                    $40,810     4,874,486  ...                   $35,248
# 5                     $9,352       739,700  ...                    $7,765
# 6                    $55,997     7,044,008  ...                   $44,177
# ..                        ...          ...  ...                        ...
# 65                        NaN          NaN  ...                        NaN
# 66                        NaN          NaN  ...                        NaN
# 67                        NaN          NaN  ...                        NaN
# 68                        NaN          NaN  ...                        NaN
# 69                        NaN          NaN  ...                        NaN
#
#        Pop_2013  Location_2013 Total Health Spending_2013     Pop_2012  \
# 2           NaN       Location      Total Health Spending          NaN
# 3   315,993,715  United States                $2,405,667   313,830,990
# 4     4,830,081        Alabama                   $33,670     4,815,588
# 5       737,068         Alaska                    $7,439       730,443
# 6     6,632,764        Arizona                   $41,728     6,554,978
# ..          ...            ...                        ...          ...
# 65          NaN            NaN                        NaN          NaN
# 66          NaN            NaN                        NaN          NaN
# 67          NaN            NaN                        NaN          NaN
# 68          NaN            NaN                        NaN          NaN
# 69          NaN            NaN                        NaN          NaN
#
#     Location_2012 Total Health Spending_2012     Pop_2011  Location_2011  \
# 2        Location      Total Health Spending          NaN       Location
# 3   United States                $2,346,962   311,556,874  United States
# 4         Alabama                   $32,740     4,799,069        Alabama
# 5          Alaska                    $7,257       722,128         Alaska
# 6         Arizona                   $40,692     6,472,643        Arizona
# ..            ...                        ...          ...            ...
# 65            NaN                        NaN          NaN            NaN
# 66            NaN                        NaN          NaN            NaN
# 67            NaN                        NaN          NaN            NaN
# 68            NaN                        NaN          NaN            NaN
# 69            NaN                        NaN          NaN            NaN
#
#    Total Health Spending_2011
# 2       Total Health Spending
# 3                 $2,254,675
# 4                    $31,262
# 5                     $6,749
# 6                    $39,329
# ..                        ...
# 65                        NaN
# 66                        NaN
# 67                        NaN
# 68                        NaN
# 69                        NaN
#
# [68 rows x 30 columns]

# %%
# Step 3: Reshape the data by organizing each year into rows
data_cleaned = pd.DataFrame()

# %%
for year in years:
    # Select location and spending columns for the specific year
    year_data = healthcare_population_raw_data[[f'Pop_{year}',f'Location_{year}', f'Total Health Spending_{year}']].copy()
    year_data.columns = ['Pop','State', 'Total Health Spending']
    year_data['Year'] = year
    data_cleaned = pd.concat([data_cleaned, year_data])

# %%
# Step 4: Remove any rows where 'State' is NaN (in case of any empty rows from combining)
data_cleaned = data_cleaned.dropna(subset=['State'])

# %%
# Cleaning Data
data_cleaned = data_cleaned[data_cleaned['State'] != "Location"] 
data_cleaned = data_cleaned[data_cleaned['State'] != "United States"]

# %%
# Step 5: Convert 'Total Health Spending' to numeric by removing any non-numeric characters
data_cleaned['Total Health Spending'] = data_cleaned['Total Health Spending'].str.replace('$', '')
# Step 5: Convert 'Total Health Spending' to numeric by removing any non-numeric characters
data_cleaned['Total Health Spending'] = data_cleaned['Total Health Spending'].str.replace(',', '').astype(float)

# %%
# Data Cleaning
data_cleaned['Pop'] = data_cleaned['Pop'].str.replace(',', '').astype(float)

# %%
# Display the cleaned data
print(data_cleaned.head(10))
data_cleaned.to_csv('healthcare_population_raw_data_cleaned.csv')

healthcare_population_raw_data_cleaned = data_cleaned
# Out:
#            Pop                 State  Total Health Spending  Year
# 4    5031864.0               Alabama                45673.0  2020
# 5     732964.0                Alaska                 9975.0  2020
# 6    7186683.0               Arizona                64980.0  2020
# 7    3014348.0              Arkansas                28300.0  2020
# 8   39503200.0            California               405451.0  2020
# 9    5785219.0              Colorado                49849.0  2020
# 10   3577586.0           Connecticut                44425.0  2020
# 11    991862.0              Delaware                12729.0  2020
# 12    670839.0  District of Columbia                10251.0  2020
# 13  21591299.0               Florida               214408.0  2020

# %%
## Data Cleaning of Coverage Data

# %%
# Load the data 
file_path = 'Data_Files_Healthcare_Project/Coverage Rates of Health Insurance Types By States.xlsx'
insurance_coverage_rates = pd.read_excel(file_path, skiprows=3)

# Step 1: Remove metadata rows 
insurance_coverage_rates = insurance_coverage_rates.iloc[1:]

#raw_data

# Drop columns by index
#healthcare_population_raw = healthcare_population_raw.drop(columns=[0, 1, 2])

insurance_coverage_rates = insurance_coverage_rates.iloc[:572]


# Display the modified DataFrame
print(insurance_coverage_rates.head(10))

#insurance_coverage_rates.to_csv('ff.csv')
#insurance_coverage_rates.columns
# Out:
#      Nation/State           Coverage    2023 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1   United States              Total  330000         20        100          0
# 2   United States       Any coverage  303800        180       92.1        0.1
# 3   United States          Uninsured   26170        183        7.9        0.1
# 4   United States            Private  221100        455         67        0.1
# 5   United States   ..Employer-based  180400        418       54.7        0.1
# 6   United States  ..Direct-purchase   45770        149       13.9          Z
# 7   United States          ..TRICARE    9088         82        2.8          Z
# 8   United States             Public  123500        279       37.4        0.1
# 9   United States         ..Medicaid   70330        316       21.3        0.1
# 10  United States         ..Medicare   61900         66       18.8          Z
#
#       2022 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 56 Unnamed: 57  \
# 1   328300         17        100          0  ...         100           0
# 2   301900        177         92        0.1  ...        84.5         0.1
# 3    26370        179          8        0.1  ...        15.5         0.1
# 4   220700        456       67.2        0.1  ...        65.8         0.1
# 5   179900        409       54.8        0.1  ...        54.9         0.1
# 6    45720        150       13.9          Z  ...        12.7         0.1
# 7     8925         74        2.7          Z  ...         2.6           Z
# 8   122000        270       37.2        0.1  ...        29.7         0.1
# 9    69710        289       21.2        0.1  ...          17         0.1
# 10   60860         60       18.5          Z  ...        14.7           Z
#
#       2009 Unnamed: 59 Unnamed: 60 Unnamed: 61    2008 Unnamed: 63  \
# 1   301500          23         100           0  298600          20
# 2   255800         235        84.9         0.1  255100         230
# 3    45670         238        15.1         0.1   43500         233
# 4   203300         379        67.4         0.1  207800         353
# 5   170600         310        56.6         0.1  175300         308
# 6    39630         154        13.1         0.1   42350         151
# 7     7639          63         2.5           Z    7615          62
# 8    85960         157        28.5         0.1   81430         147
# 9    48770         174        16.2         0.1   45230         146
# 10   43490          55        14.4           Z   42650          60
#
#    Unnamed: 64 Unnamed: 65
# 1          100           0
# 2         85.4         0.1
# 3         14.6         0.1
# 4         69.6         0.1
# 5         58.7         0.1
# 6         14.2         0.1
# 7          2.6           Z
# 8         27.3           Z
# 9         15.1           Z
# 10        14.3           Z
#
# [10 rows x 66 columns]

# %%
# Define the years and suffixes for renaming
years = range(2023, 2007, -1)
suffixes = ['estimate', 'MOError1', 'Percent', 'MOError2']

# Start column index based on your data structure (D is index 3)
start_index = 2

# Loop over years and suffixes to rename columns
for year in years:
    for i, suffix in enumerate(suffixes):
        if start_index + i < len(insurance_coverage_rates.columns):
            insurance_coverage_rates.columns.values[start_index + i] = f'{year}_{suffix}'
    start_index += len(suffixes)  # Move to the next set of columns for the next year

# Verify the column names
print(insurance_coverage_rates.columns)
# Out:
# Index(['Nation/State', 'Coverage', '2023_estimate', '2023_MOError1',
#        '2023_Percent', '2023_MOError2', '2022_estimate', '2022_MOError1',
#        '2022_Percent', '2022_MOError2', '2021_estimate', '2021_MOError1',
#        '2021_Percent', '2021_MOError2', '2020_estimate', '2020_MOError1',
#        '2020_Percent', '2020_MOError2', '2019_estimate', '2019_MOError1',
#        '2019_Percent', '2019_MOError2', '2018_estimate', '2018_MOError1',
#        '2018_Percent', '2018_MOError2', '2017_estimate', '2017_MOError1',
#        '2017_Percent', '2017_MOError2', '2016_estimate', '2016_MOError1',
#        '2016_Percent', '2016_MOError2', '2015_estimate', '2015_MOError1',
#        '2015_Percent', '2015_MOError2', '2014_estimate', '2014_MOError1',
#        '2014_Percent', '2014_MOError2', '2013_estimate', '2013_MOError1',
#        '2013_Percent', '2013_MOError2', '2012_estimate', '2012_MOError1',
#        '2012_Percent', '2012_MOError2', '2011_estimate', '2011_MOError1',
#        '2011_Percent', '2011_MOError2', '2010_estimate', '2010_MOError1',
#        '2010_Percent', '2010_MOError2', '2009_estimate', '2009_MOError1',
#        '2009_Percent', '2009_MOError2', '2008_estimate', '2008_MOError1',
#        '2008_Percent', '2008_MOError2'],
#       dtype='object')

# %%
# Melt DataFrame to organize year and metric columns into rows
melted_df = insurance_coverage_rates.melt(
    id_vars=['Nation/State', 'Coverage'],  # Keep these columns as identifiers
    var_name='Metric',  # New column for the combined Year and Metric
    value_name='Value'  # New column for the values
)

# Rename columns to match the desired output
melted_df = melted_df.rename(columns={
    'Nation/State': 'Nation',
    'Coverage': 'Coverage'
})

# Reorder columns to match desired output format
melted_df = melted_df[['Nation', 'Coverage', 'Metric', 'Value']]

# Display the transformed DataFrame
print(melted_df.head())
# Out:
#           Nation          Coverage         Metric   Value
# 0  United States             Total  2023_estimate  330000
# 1  United States      Any coverage  2023_estimate  303800
# 2  United States         Uninsured  2023_estimate   26170
# 3  United States           Private  2023_estimate  221100
# 4  United States  ..Employer-based  2023_estimate  180400

# %%
# Remove leading '..' from the Coverage column
melted_df['Coverage'] = melted_df['Coverage'].str.replace('.. ', '')
melted_df['Coverage'] = melted_df['Coverage'].str.replace('..', '')
melted_df = melted_df[melted_df['Nation'] != "United States"] 

# Display the updated DataFrame
print(melted_df[['Coverage']].head())
# Out:
#           Coverage
# 11           Total
# 12    Any coverage
# 13       Uninsured
# 14         Private
# 15  Employer-based

# %%
print(melted_df.head())
# Out:
#      Nation        Coverage         Metric Value
# 11  Alabama           Total  2023_estimate  5022
# 12  Alabama    Any coverage  2023_estimate  4596
# 13  Alabama       Uninsured  2023_estimate   426
# 14  Alabama         Private  2023_estimate  3368
# 15  Alabama  Employer-based  2023_estimate  2694

# %%
# Ensure the Metric column is treated as strings
melted_df['Metric'] = melted_df['Metric'].astype(str)

# Split the Metric column into Year and Metric
melted_df[['Year', 'Metric']] = melted_df['Metric'].str.split('_', expand=True)

# Reorder columns to match the desired format
#melted_df = melted_df[['Nation', 'Coverage', 'Metric', 'Value', 'Year']]

# Display the updated DataFrame
print(melted_df.head())
# Out:
#      Nation        Coverage    Metric Value  Year
# 11  Alabama           Total  estimate  5022  2023
# 12  Alabama    Any coverage  estimate  4596  2023
# 13  Alabama       Uninsured  estimate   426  2023
# 14  Alabama         Private  estimate  3368  2023
# 15  Alabama  Employer-based  estimate  2694  2023

# %%
melted_df.to_csv('insurance_coverage_rates_cleaned.csv')
insurance_coverage_rates_cleaned = melted_df

# %%
## Analysis

# %%
# Load the cleaned datasets
population_data = pd.read_csv('healthcare_population_raw_data_cleaned.csv')
insurance_data = pd.read_csv('insurance_coverage_rates_cleaned.csv')
expenditure_data = pd.read_csv('raw_data_cleaned.csv')

# %%
## How has the proportion of insured versus uninsured people changed yearly across states from 2011 to 2020?

# %%
#Load Data
df = insurance_data
df = df[df['Year'] != 2020] 
df = df[df['Metric'] != 'Percent'] 
df = df[df['Metric'] != 'MOError1'] 
df = df[df['Metric'] != 'MOError2'] 

# Filter data to get rows where `Coverage` is "Any coverage" or "Total"
coverage_data = df[df['Coverage'].isin(['Any coverage', 'Uninsured'])]

coverage_data['Value'] =coverage_data['Value'].str.replace(',', '')
coverage_data['Value'] =coverage_data['Value'].astype(float)

# Pivot the table to have "Any coverage" and "Total" as columns for each state and year
coverage_pivot = coverage_data.pivot_table(
    index=['Nation', 'Year'],
    columns='Coverage',
    values='Value'
).reset_index()

# Calculate the percentage of insured people (Any coverage / Total * 100)
coverage_pivot['Percent Insured'] = (coverage_pivot['Any coverage'] / (coverage_pivot['Uninsured']+coverage_pivot['Any coverage'] ) )* 100

# Display the results
#print(coverage_pivot[['Nation', 'Year', 'Percent Insured']].head())

# Optionally, save the results to a new CSV file
coverage_pivot[['Nation', 'Year', 'Percent Insured']].to_csv('percent_insured_by_state_year.csv', index=False)


# Correcting the pivot statement
heatmap_data = coverage_pivot.pivot(index='Nation', columns='Year', values='Percent Insured')

# Plot the heatmap
plt.figure(figsize=(18, 20))
sns.heatmap(heatmap_data, annot=True, fmt=".1f", cmap="RdYlGn", cbar_kws={'label': 'Percent Insured'}, cbar=False)
plt.title('Percentage of Insured Coverage by State and Year')
plt.xlabel('Year')
plt.ylabel('')
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.show()

# %%
# What are the trends in healthcare insurance rates from 2011 to 2020, and how do they vary by state?

# %%
#Load Data
df = insurance_data
df = df[df['Year'] != 2020] 
df = df[df['Metric'] != 'Percent'] 
df = df[df['Metric'] != 'MOError1'] 
df = df[df['Metric'] != 'MOError2'] 

# Filter data to get rows where `Coverage` is "Any coverage" or "Total"
coverage_data = df[df['Coverage'].isin(['Any coverage', 'Uninsured'])]

coverage_data['Value'] =coverage_data['Value'].str.replace(',', '')
coverage_data['Value'] =coverage_data['Value'].astype(float)

# Pivot the table to have "Any coverage" and "Total" as columns for each state and year
coverage_pivot = coverage_data.pivot_table(
    index=['Nation', 'Year'],
    columns='Coverage',
    values='Value'
).reset_index()

# Calculate the percentage of insured people (Any coverage / Total * 100)
coverage_pivot['Percent Insured'] = (coverage_pivot['Any coverage'] / (coverage_pivot['Uninsured']+coverage_pivot['Any coverage'] ) )* 100

# Display the results
#print(coverage_pivot[['Nation', 'Year', 'Percent Insured']].head())

# Optionally, save the results to a new CSV file
coverage_pivot[['Nation', 'Year', 'Percent Insured']].to_csv('percent_insured_by_state_year.csv', index=False)


# Correcting the pivot statement
heatmap_data = coverage_pivot.pivot(index='Nation', columns='Year', values='Percent Insured')

# Plot the heatmap
plt.figure(figsize=(18, 20))
sns.heatmap(heatmap_data, annot=True, fmt=".1f", cmap="RdYlGn", cbar_kws={'label': 'Percent Insured'}, cbar=False)
plt.title('Percentage of Insured Coverage by State and Year')
plt.xlabel('Year')
plt.ylabel('')
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.show()

# %%
## What are the trends in private insurance enrollment by state from 2011 to 2020?

# %%
#Load Data
df = insurance_data
df = df[df['Year'] != 2020] 
df = df[df['Metric'] != 'Percent'] 
df = df[df['Metric'] != 'MOError1'] 
df = df[df['Metric'] != 'MOError2'] 

# Filter data to get rows where `Coverage` is "Any coverage" or "Total"
coverage_data = df[df['Coverage'].isin(['Private'])]

coverage_data['Value'] =coverage_data['Value'].str.replace(',', '')
coverage_data['Value'] =coverage_data['Value'].astype(float)

# Pivot the table to have "Any coverage" and "Total" as columns for each state and year
coverage_pivot = coverage_data.pivot_table(
    index=['Year'],
    columns='Coverage',
    values='Value'
).reset_index()

# Calculate the percentage of insured people (Any coverage / Total * 100)
#coverage_pivot['Percent Insured'] = (coverage_pivot['Any coverage'] / (coverage_pivot['Uninsured']+coverage_pivot['Any coverage'] ) )* 100

# Display the results
#print(coverage_pivot[['Nation', 'Year', 'Percent Insured']].head())

# Optionally, save the results to a new CSV file
#coverage_pivot[['Nation', 'Year', 'Percent Insured']].to_csv('percent_insured_by_state_year.csv', index=False)

print(coverage_pivot)


# Plotting the line chart for "Private" insurance coverage over the years
plt.figure(figsize=(10, 6))
sns.lineplot(data=coverage_pivot, x='Year', y='Private', marker='o')

# Add labels and title
plt.title('Private Insurance Coverage Over the Years')
plt.xlabel('Year')
plt.ylabel('Coverage Rates')
plt.grid(True)
plt.show()
# Out:
# Coverage  Year      Private
# 0         2008  4074.490196
# 1         2009  3986.490196
# 2         2010  3926.941176
# 3         2011  3918.960784
# 4         2012  3945.333333
# 5         2013  3968.470588
# 6         2014  4085.000000
# 7         2015  4186.803922
# 8         2016  4232.470588
# 9         2017  4253.980392
# 10        2018  4267.254902
# 11        2019  4270.784314
# 12        2021  4295.490196
# 13        2022  4326.627451
# 14        2023  4335.960784

# %%
# Filter only relevant coverage types 
#insurance_data = insurance_data[insurance_data['Coverage'].isin(['Private', 'Public', 'Other'])]

# Plotting the line chart for "Private" insurance coverage over the years
plt.figure(figsize=(10, 6))
sns.lineplot(data=coverage_pivot, x='Year', y='Private', marker='o')

# Add labels and title
plt.title('Private Insurance Coverage Over the Years')
plt.xlabel('Year')
plt.ylabel('Coverage Rates in Millions')

# Format y-axis labels to show 0 decimal places
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.0f}'))

# Remove grid lines
plt.grid(False)

# Add data labels for each point
for x, y in zip(coverage_pivot['Year'], coverage_pivot['Private']):
    plt.text(x, y, f'{y:.0f}', ha='center', va='bottom')

plt.show()

# %%
# Percent Insured

# %%
#Load Data
df = insurance_data
df = df[df['Year'] != 2020] 
df = df[df['Metric'] != 'Percent'] 
df = df[df['Metric'] != 'MOError1'] 
df = df[df['Metric'] != 'MOError2'] 

# Filter data to get rows where `Coverage` is "Any coverage" or "Total"
coverage_data = df[df['Coverage'].isin(['Any coverage', 'Uninsured'])]

coverage_data['Value'] =coverage_data['Value'].str.replace(',', '')
coverage_data['Value'] = coverage_data['Value'].str.replace("'",'')

# %%
coverage_data
# Out:
#        Unnamed: 0         Nation      Coverage    Metric Value  Year
# 1              12        Alabama  Any coverage  estimate  4596  2023
# 2              13        Alabama     Uninsured  estimate   426  2023
# 12             23         Alaska  Any coverage  estimate   629  2023
# 13             24         Alaska     Uninsured  estimate    73  2023
# 23             34        Arizona  Any coverage  estimate  6594  2023
# ...           ...            ...           ...       ...   ...   ...
# 34190       34861  West Virginia     Uninsured  estimate   265  2008
# 34200       34871      Wisconsin  Any coverage  estimate  5051  2008
# 34201       34872      Wisconsin     Uninsured  estimate   489  2008
# 34211       34882        Wyoming  Any coverage  estimate   452  2008
# 34212       34883        Wyoming     Uninsured  estimate    72  2008
#
# [1530 rows x 6 columns]

# %%
coverage_data.to_csv('Data_Files_Healthcare_Project/ff.csv')

# %%
#coverage_data['Value'] =coverage_data['Value'].astype(float)

# Convert the 'Value' column to numeric, forcing errors to NaN
#coverage_data['Value'] = pd.to_numeric(coverage_data['Value'], errors='coerce')


#coverage_data = insurance_data[insurance_data['Coverage'].isin(['Any coverage', 'Uninsured', 'Private', 'Public'])]


# Convert the 'Value' column to numeric, turning errors into NaN
coverage_data['Value'] = pd.to_numeric(coverage_data['Value'], errors='coerce')

# Check for NaN values after conversion
print(coverage_data[coverage_data['Value'].isna()])
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Nation, Coverage, Metric, Value, Year]
# Index: []

# %%
coverage_data
# Out:
#        Unnamed: 0         Nation      Coverage    Metric  Value  Year
# 1              12        Alabama  Any coverage  estimate   4596  2023
# 2              13        Alabama     Uninsured  estimate    426  2023
# 12             23         Alaska  Any coverage  estimate    629  2023
# 13             24         Alaska     Uninsured  estimate     73  2023
# 23             34        Arizona  Any coverage  estimate   6594  2023
# ...           ...            ...           ...       ...    ...   ...
# 34190       34861  West Virginia     Uninsured  estimate    265  2008
# 34200       34871      Wisconsin  Any coverage  estimate   5051  2008
# 34201       34872      Wisconsin     Uninsured  estimate    489  2008
# 34211       34882        Wyoming  Any coverage  estimate    452  2008
# 34212       34883        Wyoming     Uninsured  estimate     72  2008
#
# [1530 rows x 6 columns]

# %%
# Pivot the table to have "Any coverage" and "Total" as columns for each state and year
coverage_pivot = coverage_data.pivot_table(
    index=[ 'Year'],
    columns='Coverage',
    values='Value',
).reset_index()

# %%
# Calculate the percentage of insured people (Any coverage / Total * 100)
coverage_pivot['Percent Insured'] = (coverage_pivot['Any coverage'] / (coverage_pivot['Uninsured']+coverage_pivot['Any coverage'] ) )* 100

print(coverage_pivot)
# Display the results
#print(coverage_pivot[['Nation', 'Year', 'Percent Insured']].head())

# Save the results to a new CSV file
#coverage_pivot[['Nation', 'Year', 'Percent Insured']].to_csv('percent_insured_by_state_year.csv', index=False)

# Correcting the pivot statement
#heatmap_data = coverage_pivot.pivot(index='Nation', columns='Year', values='Percent Insured')

# Plotting the line chart for "Private" insurance coverage over the years
plt.figure(figsize=(10, 6))
sns.lineplot(data=coverage_pivot, x='Year', y='Percent Insured', marker='o')

# Add labels and title
plt.title('Percent Insured Coverage Over the Years')
plt.xlabel('Year')
plt.ylabel('Coverage Percentage')
plt.grid(True)
plt.show()
# Out:
# Coverage  Year  Any coverage   Uninsured  Percent Insured
# 0         2008   5001.215686  852.941176        85.430162
# 1         2009   5016.176471  895.411765        84.853279
# 2         2010   5040.803922  925.705882        84.484968
# 3         2011   5101.941176  909.294118        84.873423
# 4         2012   5162.725490  894.392157        85.234030
# 5         2013   5215.313725  885.882353        85.480185
# 6         2014   5435.705882  719.058824        88.317038
# 7         2015   5621.725490  583.490196        90.596778
# 8         2016   5703.274510  535.392157        91.418164
# 9         2017   5740.392157  549.431373        91.264757
# 10        2018   5758.666667  560.058824        91.136522
# 11        2019   5754.901961  581.156863        90.827786
# 12        2021   5856.529412  553.450980        91.365793
# 13        2022   5920.666667  517.058824        91.968300
# 14        2023   5957.235294  513.019608        92.071107

# %%
# Plotting the line chart for "Private" insurance coverage over the years
plt.figure(figsize=(10, 6))
sns.lineplot(data=coverage_pivot, x='Year', y='Percent Insured', marker='o')

# Add labels and title
plt.title('Percent Insured Coverage Over the Years')
plt.xlabel('Year')
plt.ylabel('Coverage Percentage')

# Format y-axis labels to show 0 decimal places
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.0f}'))

# Remove grid lines
plt.grid(False)

# Add data labels for each point
for x, y in zip(coverage_pivot['Year'], coverage_pivot['Percent Insured']):
    plt.text(x, y, f'{y:.0f}', ha='center', va='bottom')

plt.show()

# %%
## What is the relationship between the number of insured people in each state and the total healthcare expenditure by state for each year from 2011 to 2020?

# %%
# Load the cleaned datasets

population_data_df = population_data[(population_data['Year'] >= 2011) & (population_data['Year'] <= 2019)]
population_data_df = population_data_df[['State','Total Health Spending','Year']]

print(population_data_df)

#population_data 
insurance_data_df = insurance_data[(insurance_data['Year'] >= 2011) & (insurance_data['Year'] <= 2019)]
insurance_data_df = insurance_data_df[insurance_data_df['Metric'] == 'estimate'] 

# Filter data to get rows where `Coverage` is "Any coverage" or "Total"
coverage_data = insurance_data_df[insurance_data_df['Coverage'].isin(['Any coverage'])]
coverage_data = coverage_data[['Nation', 'Value', 'Year']]

#print(population_data_df)

print(coverage_data)

# Merge DataFrames on multiple columns
merged_df = pd.merge(
    population_data_df,
    coverage_data,
    left_on=['State', 'Year'],
    right_on=['Nation', 'Year'],
    how='inner'
)

print(merged_df)
# Out:
#              State  Total Health Spending  Year
# 51         Alabama                42903.0  2019
# 52          Alaska                 9702.0  2019
# 53         Arizona                59392.0  2019
# 54        Arkansas                26744.0  2019
# 55      California               379715.0  2019
# ..             ...                    ...   ...
# 505       Virginia                55019.0  2011
# 506     Washington                47939.0  2011
# 507  West Virginia                15242.0  2011
# 508      Wisconsin                44646.0  2011
# 509        Wyoming                 4246.0  2011
#
# [459 rows x 3 columns]
#               Nation  Value  Year
# 8977         Alabama   4354  2019
# 8988          Alaska    620  2019
# 8999         Arizona   6357  2019
# 9010        Arkansas   2692  2019
# 9021      California  36000  2019
# ...              ...    ...   ...
# 27435       Virginia   6904  2011
# 27446     Washington   5764  2011
# 27457  West Virginia   1554  2011
# 27468      Wisconsin   5127  2011
# 27479        Wyoming    473  2011
#
# [459 rows x 3 columns]
#              State  Total Health Spending  Year         Nation  Value
# 0          Alabama                42903.0  2019        Alabama   4354
# 1           Alaska                 9702.0  2019         Alaska    620
# 2          Arizona                59392.0  2019        Arizona   6357
# 3         Arkansas                26744.0  2019       Arkansas   2692
# 4       California               379715.0  2019     California  36000
# ..             ...                    ...   ...            ...    ...
# 454       Virginia                55019.0  2011       Virginia   6904
# 455     Washington                47939.0  2011     Washington   5764
# 456  West Virginia                15242.0  2011  West Virginia   1554
# 457      Wisconsin                44646.0  2011      Wisconsin   5127
# 458        Wyoming                 4246.0  2011        Wyoming    473
#
# [459 rows x 5 columns]

# %%
merged_df['Value'] = pd.to_numeric(merged_df['Value'].str.replace(",",""))

# %%
# Verify merged_df exists and has the correct columns 
if 'Value' in merged_df.columns and 'Total Health Spending' in merged_df.columns: 
    x_values = merged_df['Value'] 
    y_values = merged_df['Total Health Spending'] 
else: 
    print("Columns 'Value' or 'Total Health Spending' are missing in merged_df") 
    print(merged_df.columns)

# %%
# Perform a Linear regression 
slpope, intercept, rvalue, pvalue, stderr= stats.linregress(x_values, y_values)
regress_values= x_values * slpope + intercept
print(regress_values)
# Out:
# 0       41544.119936
# 1        5766.155764
# 2       60736.209449
# 3       25619.380661
# 4      344765.719886
#            ...
# 454     65977.384168
# 455     55054.277806
# 456     14715.437643
# 457     48950.752584
# 458      4357.649943
# Name: Value, Length: 459, dtype: float64

# %%
## merged_data: 'Insured People', 'Healthcare Expenditure', 'Year', and 'State'

x_values= merged_df['Value']
y_values= merged_df['Total Health Spending']
plt.figure(figsize=(12, 8))
#merged_df['Year'] = merged_df['Year'].astype('category')

sns.scatterplot(data=merged_df, x='Value', y='Total Health Spending', hue='Year', palette='viridis', s=50)
#sns.regplot(data=merged_df, x='Value', y='Total Health Spending', scatter=False, color='gray', line_kws={'linestyle':'--'})
plt.plot(x_values, regress_values, "r-" )
plt.title('Relationship between Insured People and Healthcare Expenditure by Year')
plt.xlabel('Number of Insured People')
plt.ylabel('Total Healthcare Expenditure')
plt.legend(title='Year')
plt.show()

# %%
# Create line equation string
line_eq = "y = " + str(round(slpope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = 9.58x +-174.48

# %%
# Print r^2-value 
print (f"r^2-value is: {rvalue**2}")
# Out:
# r^2-value is: 0.9757905141302595

# %%
# Load the cleaned datasets

population_data_df = population_data[(population_data['Year'] >= 2011) & (population_data['Year'] <= 2019)]
population_data_df = population_data_df[['State','Total Health Spending','Year']]


#population_data 
insurance_data_df = insurance_data[(insurance_data['Year'] >= 2011) & (insurance_data['Year'] <= 2019)]
insurance_data_df = insurance_data_df[insurance_data_df['Coverage'] == 'Private'] 
insurance_data_df

# Merge DataFrames on multiple columns
merged_df = pd.merge(
    population_data_df,
    insurance_data_df,
    left_on=['State', 'Year'],
    right_on=['Nation', 'Year'],
    how= 'inner'
)
merged_df
# Out:
#           State  Total Health Spending  Year  Unnamed: 0     Nation Coverage  \
# 0       Alabama                42903.0  2019        9166    Alabama  Private
# 1       Alabama                42903.0  2019        9738    Alabama  Private
# 2       Alabama                42903.0  2019       10310    Alabama  Private
# 3       Alabama                42903.0  2019       10882    Alabama  Private
# 4        Alaska                 9702.0  2019        9177     Alaska  Private
# ...         ...                    ...   ...         ...        ...      ...
# 1831  Wisconsin                44646.0  2011       29725  Wisconsin  Private
# 1832    Wyoming                 4246.0  2011       28020    Wyoming  Private
# 1833    Wyoming                 4246.0  2011       28592    Wyoming  Private
# 1834    Wyoming                 4246.0  2011       29164    Wyoming  Private
# 1835    Wyoming                 4246.0  2011       29736    Wyoming  Private
#
#         Metric Value
# 0     estimate  3228
# 1     MOError1    27
# 2      Percent  66.9
# 3     MOError2   0.6
# 4     estimate   457
# ...        ...   ...
# 1831  MOError2   0.4
# 1832  estimate   396
# 1833  MOError1     9
# 1834   Percent  70.9
# 1835  MOError2   1.6
#
# [1836 rows x 8 columns]

# %%
merged_df['Value'] = pd.to_numeric(merged_df['Value'].str.replace(",",""))

# %%
# Perform a Linear regression 
slpope, intercept, rvalue, pvalue, stderr= stats.linregress(x_values, y_values)
regress_values= x_values * slpope + intercept
print(regress_values)
# Out:
# 0       41544.119936
# 1        5766.155764
# 2       60736.209449
# 3       25619.380661
# 4      344765.719886
#            ...
# 454     65977.384168
# 455     55054.277806
# 456     14715.437643
# 457     48950.752584
# 458      4357.649943
# Name: Value, Length: 459, dtype: float64

# %%
print("Shape of x_values:", x_values.shape) 
print("Shape of regress_values:", regress_values.shape)
# Out:
# Shape of x_values: (459,)
# Shape of regress_values: (459,)

# %%
merged_df = merged_df.dropna(subset=['Value', 'Total Health Spending']) 
x_values = merged_df['Value'] 
y_values = merged_df['Total Health Spending']

# %%
slope, intercept, _, _, _ = stats.linregress(x_values, y_values) 
regress_values = x_values * slope + intercept

# %%
assert len(x_values) == len(regress_values), "x_values and regress_values must have the same length!"

# %%
## merged_data: 'Public Insured', 'Healthcare Expenditure', 'Year', and 'State'
x_values= merged_df['Value']
y_values= merged_df['Total Health Spending']

plt.figure(figsize=(12, 8))
sns.scatterplot(data=merged_df, x='Value', y='Total Health Spending', hue='Year', palette='viridis', s=50)
#sns.regplot(data=merged_df, x='Value', y='Total Health Spending', scatter=False, color='gray', line_kws={'linestyle':'--'}
plt.plot(x_values, regress_values, "r-" )
plt.title('Relationship between Public and Healthcare Expenditure by Year')
plt.xlabel('Public Insured')
plt.ylabel('Total Healthcare Expenditure')
plt.legend(title='Year')
plt.show()

# %%
# Create line equation string
line_eq = "y = " + str(round(slpope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = 9.58x +44013.91

# %%
# Print r^2-value 
print (f"r^2-value is: {rvalue**2}")
# Out:
# r^2-value is: 0.9757905141302595

# %%
merged_df
# Out:
#           State  Total Health Spending  Year  Unnamed: 0     Nation Coverage  \
# 0       Alabama                42903.0  2019        9166    Alabama  Private
# 1       Alabama                42903.0  2019        9738    Alabama  Private
# 2       Alabama                42903.0  2019       10310    Alabama  Private
# 3       Alabama                42903.0  2019       10882    Alabama  Private
# 4        Alaska                 9702.0  2019        9177     Alaska  Private
# ...         ...                    ...   ...         ...        ...      ...
# 1831  Wisconsin                44646.0  2011       29725  Wisconsin  Private
# 1832    Wyoming                 4246.0  2011       28020    Wyoming  Private
# 1833    Wyoming                 4246.0  2011       28592    Wyoming  Private
# 1834    Wyoming                 4246.0  2011       29164    Wyoming  Private
# 1835    Wyoming                 4246.0  2011       29736    Wyoming  Private
#
#         Metric   Value
# 0     estimate  3228.0
# 1     MOError1    27.0
# 2      Percent    66.9
# 3     MOError2     0.6
# 4     estimate   457.0
# ...        ...     ...
# 1831  MOError2     0.4
# 1832  estimate   396.0
# 1833  MOError1     9.0
# 1834   Percent    70.9
# 1835  MOError2     1.6
#
# [1836 rows x 8 columns]

# %%
## merged_data: 'Insured People', 'Healthcare Expenditure', 'Year', and 'State'
plt.figure(figsize=(12, 8))
#merged_df['Year'] = merged_df['Year'].astype('category')

sns.scatterplot(data=merged_df, x='Value', y='Total Health Spending', hue='Year', palette='viridis', s=50)
#sns.regplot(data=merged_df, x='Value', y='Total Health Spending', scatter=False, color='gray', line_kws={'linestyle':'--'})
plt.title('Relationship between Insured People and Healthcare Expenditure by Year')
plt.xlabel('Number of Insured People')
plt.ylabel('Total Healthcare Expenditure')
plt.legend(title='Year')
plt.show()

# %%
# Load the cleaned datasets

population_data_df = population_data[(population_data['Year'] >= 2011) & (population_data['Year'] <= 2019)]
population_data_df = population_data_df[['State','Total Health Spending','Year']]


#population_data 
insurance_data_df = insurance_data[(insurance_data['Year'] >= 2011) & (insurance_data['Year'] <= 2019)]
insurance_data_df = insurance_data_df[insurance_data_df['Coverage'] == 'Private'] 
insurance_data_df

# Merge DataFrames on multiple columns
merged_df = pd.merge(
    population_data_df,
    insurance_data_df,
    left_on=['State', 'Year'],
    right_on=['Nation', 'Year'],
    how= 'inner'
)
merged_df
# Out:
#           State  Total Health Spending  Year  Unnamed: 0     Nation Coverage  \
# 0       Alabama                42903.0  2019        9166    Alabama  Private
# 1       Alabama                42903.0  2019        9738    Alabama  Private
# 2       Alabama                42903.0  2019       10310    Alabama  Private
# 3       Alabama                42903.0  2019       10882    Alabama  Private
# 4        Alaska                 9702.0  2019        9177     Alaska  Private
# ...         ...                    ...   ...         ...        ...      ...
# 1831  Wisconsin                44646.0  2011       29725  Wisconsin  Private
# 1832    Wyoming                 4246.0  2011       28020    Wyoming  Private
# 1833    Wyoming                 4246.0  2011       28592    Wyoming  Private
# 1834    Wyoming                 4246.0  2011       29164    Wyoming  Private
# 1835    Wyoming                 4246.0  2011       29736    Wyoming  Private
#
#         Metric Value
# 0     estimate  3228
# 1     MOError1    27
# 2      Percent  66.9
# 3     MOError2   0.6
# 4     estimate   457
# ...        ...   ...
# 1831  MOError2   0.4
# 1832  estimate   396
# 1833  MOError1     9
# 1834   Percent  70.9
# 1835  MOError2   1.6
#
# [1836 rows x 8 columns]

# %%
# Load the cleaned datasets

population_data_df = population_data[(population_data['Year'] >= 2011) & (population_data['Year'] <= 2019)]
population_data_df = population_data_df[['State','Total Health Spending','Year']]

#population_data 
insurance_data_df = insurance_data[(insurance_data['Year'] >= 2011) & (insurance_data['Year'] <= 2019)]
insurance_data_df = insurance_data_df[insurance_data_df['Coverage'] == 'Public'] 
insurance_data_df

# Merge DataFrames on multiple columns
merged_df = pd.merge(
    population_data_df,
    insurance_data_df,
    left_on=['State', 'Year'],
    right_on=['Nation', 'Year'],
    how= 'inner'
)
merged_df
# Out:
#           State  Total Health Spending  Year  Unnamed: 0     Nation Coverage  \
# 0       Alabama                42903.0  2019        9170    Alabama   Public
# 1       Alabama                42903.0  2019        9742    Alabama   Public
# 2       Alabama                42903.0  2019       10314    Alabama   Public
# 3       Alabama                42903.0  2019       10886    Alabama   Public
# 4        Alaska                 9702.0  2019        9181     Alaska   Public
# ...         ...                    ...   ...         ...        ...      ...
# 1831  Wisconsin                44646.0  2011       29729  Wisconsin   Public
# 1832    Wyoming                 4246.0  2011       28024    Wyoming   Public
# 1833    Wyoming                 4246.0  2011       28596    Wyoming   Public
# 1834    Wyoming                 4246.0  2011       29168    Wyoming   Public
# 1835    Wyoming                 4246.0  2011       29740    Wyoming   Public
#
#         Metric Value
# 0     estimate  1797
# 1     MOError1    24
# 2      Percent  37.3
# 3     MOError2   0.5
# 4     estimate   248
# ...        ...   ...
# 1831  MOError2   0.4
# 1832  estimate   139
# 1833  MOError1     5
# 1834   Percent  24.9
# 1835  MOError2     1
#
# [1836 rows x 8 columns]

# %%
# Load data
percent_insured_by_state_year = "Data_Files_Healthcare_Project/percent_insured_by_state_year.csv"
percent_insured_by_state_year = pd.read_csv("percent_insured_by_state_year.csv")
state_insured_df = percent_insured_by_state_year[(percent_insured_by_state_year['Year'] >= 2011) & (percent_insured_by_state_year['Year'] <= 2019)]
state_insured_df = state_insured_df[['Nation', 'Year', 'Percent Insured']]
state_insured_df
# Out:
#       Nation  Year  Percent Insured
# 3    Alabama  2011        85.720339
# 4    Alabama  2012        86.669479
# 5    Alabama  2013        86.435331
# 6    Alabama  2014        87.853996
# 7    Alabama  2015        89.876595
# ..       ...   ...              ...
# 757  Wyoming  2015        88.541667
# 758  Wyoming  2016        88.388215
# 759  Wyoming  2017        87.697715
# 760  Wyoming  2018        89.594356
# 761  Wyoming  2019        87.697715
#
# [459 rows x 3 columns]

# %%
# Load the cleaned datasets

population_data_df = population_data[(population_data['Year'] >= 2011) & (population_data['Year'] <= 2019)]
population_data_df = population_data_df[['State','Total Health Spending','Year']]

# percentage coverage data
state_insured_df= percent_insured_by_state_year[(percent_insured_by_state_year['Year'] >= 2011) & (percent_insured_by_state_year['Year'] <= 2019)]
state_insured_df= state_insured_df[['Nation', 'Year', 'Percent Insured']]
state_insured_df
# Merge DataFrames on multiple columns
merged_df = pd.merge(
    population_data_df,
    state_insured_df,
    left_on=['State', 'Year'],
    right_on=['Nation', 'Year'],
    how= 'inner'
)
merged_df
# Out:
#              State  Total Health Spending  Year         Nation  \
# 0          Alabama                42903.0  2019        Alabama
# 1           Alaska                 9702.0  2019         Alaska
# 2          Arizona                59392.0  2019        Arizona
# 3         Arkansas                26744.0  2019       Arkansas
# 4       California               379715.0  2019     California
# ..             ...                    ...   ...            ...
# 454       Virginia                55019.0  2011       Virginia
# 455     Washington                47939.0  2011     Washington
# 456  West Virginia                15242.0  2011  West Virginia
# 457      Wisconsin                44646.0  2011      Wisconsin
# 458        Wyoming                 4246.0  2011        Wyoming
#
#      Percent Insured
# 0          90.275762
# 1          87.818697
# 2          88.710578
# 3          90.853864
# 4          92.302959
# ..               ...
# 454        87.536452
# 455        85.812119
# 456        85.104053
# 457        91.001065
# 458        84.615385
#
# [459 rows x 5 columns]

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data= state_insured_df, x='Nation', y='Percent Insured', hue='Year', palette='viridis', s=50)
#sns.regplot(data=merged_df, x='Value', y='Percent Inusured', scatter=False, color='gray', line_kws={'linestyle':'--'})
plt.title('Relationship between State and Percent of State by Year')
plt.xlabel('Nation')
plt.ylabel('Percent Insured')
plt.legend(title='Year')
plt.show()

# %%
# Filter data for 2019 
spending_2019 = population_data_df[population_data_df['Year'] == 2019] 

# Sort by spending and take top/bottom states 
top_spending = spending_2019.sort_values(by='Total Health Spending', ascending=False).head(10) 

plt.figure(figsize=(12, 6)) 
sns.barplot(data=top_spending, x='Total Health Spending', y='State', palette='viridis') 
plt.title('Top 10 States by Total Healthcare Spending in 2019') 
plt.xlabel('Total Health Spending') 
plt.ylabel('State') 
plt.show()

# %%
# Distribution of healthcare expenditures across states.
plt.figure(figsize=(10, 6)) 
sns.histplot(population_data_df['Total Health Spending'], bins=20, kde=True, color='skyblue') 
plt.title('Distribution of Total Healthcare Spending Across States') 
plt.xlabel('Total Health Spending') 
plt.ylabel('Frequency') 
plt.show()

# %%
# pivot_data for 'State', 'Year', and 'Total Health Spending' 
pivot_data = data_cleaned.pivot(index='State', columns='Year', values='Total Health Spending')
pivot_data = pivot_data.fillna(0)  

# Calculate the mean healthcare expenditure across all states, yearly
us_expenditure = pivot_data.mean(axis=0)  # Change to pivot_data.sum(axis=0) if you want total expenditure
# Select 5 statess for preliminary visualization
selected_states = ['California', 'Texas', 'New York', 'Florida', 'Illinois']
plot_data = pivot_data.loc[selected_states]
# Plot the data
plt.figure(figsize=(12, 8))
# Plot lines for selected states
for state in selected_states:
    plt.plot(plot_data.columns, plot_data.loc[state], label=state)
# Plot the US average line
plt.plot(us_expenditure.index, us_expenditure, label='US Average', color='black')
# Customize the plot
plt.title('Healthcare Expenditure Across States (2011-2020)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Expenditure (in millions)', fontsize=14)
plt.legend(title='Legend')
plt.grid(True)
plt.show()

# %%
# Load Data 
df = insurance_data 
df = df[df['Year'] != 2020] 
df = df[~df['Metric'].isin(['Percent', 'MOError1', 'MOError2'])] 

# Filter data to get rows where `Coverage` is "Public" 
coverage_data = df[df['Coverage'] == 'Public'] 

# Check if any data is available for the filter 
if coverage_data.empty: 
    print("No data available for 'Public' coverage.") 
else: 
    # Clean and convert 'Value' column to numeric 
    coverage_data['Value'] = coverage_data['Value'].str.replace(',', '').astype(float) 
    
    # Pivot table by year and coverage type 
    coverage_pivot = coverage_data.pivot_table( 
        index=['Year'], 
        columns='Coverage', 
        values='Value' 
    ).reset_index() 

    # Check if pivot table has data for plotting 
    if coverage_pivot.empty: 
        print("Pivot table is empty. No data to plot.") 
    else: 
        # Plot line for "Public" insurance coverage over the years 
        plt.figure(figsize=(10, 6)) 
        sns.lineplot(data=coverage_pivot, x='Year', y='Public', marker='o') 
    
        # Labels and title 
        plt.title('Public Insurance Coverage Over the Years') 
        plt.xlabel('Year') 
        plt.ylabel('Coverage Rates') 
        plt.grid(True) 
        plt.show()
